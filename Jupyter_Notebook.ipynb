# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Abdul Hannan__ </br>
# Lecturer at University of the Punjab, Lahore

# %% [markdown]
# _I am an Industrial Engineer and also a technophile. As we all know, in this digital world we depend on data for forecasting and predictions. Therefore, I entered in this field to be a data scientist and get the most sexiest job all around the globe._

# %% [markdown]
# ### Product of two numbers

# %% [markdown]
# ```py
# print(2*4)
# ```

# %% [markdown]
# Sr. | Name| ID
# ---|---|---
# 1.|Daniel|1234
# 2.|Naseer|2345
# ___
#
# > print(3*5)
